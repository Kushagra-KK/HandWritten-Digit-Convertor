# %%
# First mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Now run the app code
import streamlit as st
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os

# Verify model path
model_path = '/content/drive/MyDrive/mnist_dcgan_generator.h5'

# Check if file exists
if not os.path.exists(model_path):
    st.error(f"Model file not found at: {model_path}")
    st.stop()

# Load generator model
generator = tf.keras.models.load_model(model_path)

# App title
st.title('Handwritten Digit Generator')

# Digit selection
digit = st.selectbox('Select digit to generate', options=list(range(10)))
num_images = st.slider('Number of images', 1, 10, 5)

if st.button('Generate Images'):
    # Create latent vectors with digit conditioning
    latent_vectors = np.random.randn(num_images, 100)

    # Add digit conditioning
    latent_vectors[:, :10] = 0
    latent_vectors[:, digit] = 1

    # Generate images
    generated_images = generator.predict(latent_vectors)

    # Display images in a grid
    cols = st.columns(5)  # 5 columns layout
    for i, img in enumerate(generated_images):
        with cols[i % 5]:
            fig, ax = plt.subplots(figsize=(2, 2))
            ax.imshow(img[:, :, 0], cmap='gray')
            ax.axis('off')
            st.pyplot(fig)
            plt.close(fig)
# Out:
# Mounted at /content/drive
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 2025-06-22 10:31:03.717 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 10:31:03.790
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /usr/local/lib/python3.11/dist-packages/colab_kernel_launcher.py [ARGUMENTS]
# 2025-06-22 10:31:03.790 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 10:31:03.792 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 10:31:03.793 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 10:31:03.794 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 10:31:03.795 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 10:31:03.796 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 10:31:03.797 Session state does not function when running a script without `streamlit run`
# 2025-06-22 10:31:03.798 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 10:31:03.798 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 10:31:03.800 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 10:31:03.801 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 10:31:03.801 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 10:31:03.802 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 10:31:03.803 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 10:31:03.804 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 10:31:03.805 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 10:31:03.806 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 10:31:03.806 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 10:31:03.807 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 10:31:03.808 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 10:31:03.808 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 10:31:03.809 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
